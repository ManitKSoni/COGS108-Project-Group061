# %%
import pandas as pd
import re
import matplotlib.pyplot as plt
import pylab as pl

# %%
# Read in our data set
df = pd.read_csv("Dataset.csv")

# %%
# Separate the sentiment into its own columns
df[['neg','neu', 'pos', 'compound']] = df.Sentiment.str.split(",",expand=True)

# Drop sentinment, we dont need it anymore
df = df.drop(['Sentiment'], axis=1);

# %%
# Clean up the extraneous parts of the strings
def just_digits(label):
    numbers = re.compile('\d+(?:\.\d+)?')
    return numbers.findall(label)[0]

df['neg'] = df['neg'].apply(just_digits).astype(float);
df['neu'] = df['neu'].apply(just_digits).astype(float);
df['pos'] = df['pos'].apply(just_digits).astype(float);
df['compound'] = df['compound'].apply(just_digits).astype(float);

# %%
# drop rows where all values are 0
df = df[(df[['neg', 'neu', 'pos', 'compound']] != 0).any(axis=1)]

# %% [markdown]
# # Data Visualization
# Now that we have our data, let us just visualize it.  This will be split up into two sections, Trump and Clinton.  And each section will have a histogram of negative, positive, and neutral sentiment data for each news source for that candidate

# %% [markdown]
# ## Trump Sentiment Analysis

# %% [markdown]
# ### CNN Articles

# %%
df.loc[(df['Candidate'] == 'Trump') & (df['News_Source'] == 'CNN')].hist(column=['neg'],bins=20);

# %%
df.loc[(df['Candidate'] == 'Trump') & (df['News_Source'] == 'CNN')].hist(column=['pos'],bins=20);

# %%
df.loc[(df['Candidate'] == 'Trump') & (df['News_Source'] == 'CNN')].hist(column=['neu'],bins=20);

# %% [markdown]
# ### Breitbart Articles

# %%
df.loc[(df['Candidate'] == 'Trump') & (df['News_Source'] == 'Breitbart')].hist(column=['neg'],bins=20);

# %%
df.loc[(df['Candidate'] == 'Trump') & (df['News_Source'] == 'Breitbart')].hist(column=['pos'],bins=20);

# %%
df.loc[(df['Candidate'] == 'Trump') & (df['News_Source'] == 'Breitbart')].hist(column=['neu'],bins=20);

# %% [markdown]
# ### New York Times Articles

# %%
df.loc[(df['Candidate'] == 'Trump') & (df['News_Source'] == 'NYT')].hist(column=['neg'],bins=20);

# %%
df.loc[(df['Candidate'] == 'Trump') & (df['News_Source'] == 'NYT')].hist(column=['pos'],bins=20);

# %%
df.loc[(df['Candidate'] == 'Trump') & (df['News_Source'] == 'NYT')].hist(column=['neu'],bins=20);

# %% [markdown]
# ## Clinton Sentiment Analysis

# %% [markdown]
# ### CNN Articles

# %%
df.loc[(df['Candidate'] == 'Hillary') & (df['News_Source'] == 'CNN')].hist(column=['neg'],bins=20);

# %%
df.loc[(df['Candidate'] == 'Hillary') & (df['News_Source'] == 'CNN')].hist(column=['pos'],bins=20);

# %%
df.loc[(df['Candidate'] == 'Hillary') & (df['News_Source'] == 'CNN')].hist(column=['neu'],bins=20);

# %% [markdown]
# ### Breitbart Articles

# %%
df.loc[(df['Candidate'] == 'Hillary') & (df['News_Source'] == 'Breitbart')].hist(column=['neg'],bins=20);

# %%
df.loc[(df['Candidate'] == 'Hillary') & (df['News_Source'] == 'Breitbart')].hist(column=['pos'],bins=20);

# %%
df.loc[(df['Candidate'] == 'Hillary') & (df['News_Source'] == 'Breitbart')].hist(column=['neu'],bins=20);

# %% [markdown]
# ### New York Times Articles

# %%
df.loc[(df['Candidate'] == 'Hillary') & (df['News_Source'] == 'NYT')].hist(column=['neg'],bins=20);

# %%
df.loc[(df['Candidate'] == 'Hillary') & (df['News_Source'] == 'NYT')].hist(column=['pos'],bins=20);

# %%
df.loc[(df['Candidate'] == 'Hillary') & (df['News_Source'] == 'NYT')].hist(column=['neu'],bins=20);

# %% [markdown]
# # Less Neutral Article Visualization
#
# So, given this data set, there were high amounts of 0's for neg/pos sentiment because there were a high amount of articles that were neutral
# So, lets look at the data again, but this time remove all articles that were neutral. This data set will show us the sentiment for articles that were not completely neutral based on a threshold of 0.8

# %%
df_noNeu = df.loc[(df['neu'] < 0.8)]

# %% [markdown]
# # Trump Sentiment Analysis

# %% [markdown]
# ### CNN Articles

# %%
df_noNeu.loc[(df_noNeu['Candidate'] == 'Trump') & (df_noNeu['News_Source'] == 'CNN')].hist(column=['neg'],bins=20);

# %%
df_noNeu.loc[(df_noNeu['Candidate'] == 'Trump') & (df_noNeu['News_Source'] == 'CNN')].hist(column=['pos'],bins=20);

# %% [markdown]
# ### Breitbart Articles

# %%
df_noNeu.loc[(df_noNeu['Candidate'] == 'Trump') & (df_noNeu['News_Source'] == 'Breitbart')].hist(column=['neg'],bins=20);

# %%
df_noNeu.loc[(df_noNeu['Candidate'] == 'Trump') & (df_noNeu['News_Source'] == 'Breitbart')].hist(column=['pos'],bins=20);

# %% [markdown]
# ### New York Times Articles

# %%
df_noNeu.loc[(df_noNeu['Candidate'] == 'Trump') & (df_noNeu['News_Source'] == 'NYT')].hist(column=['neg'],bins=20);

# %%
df_noNeu.loc[(df_noNeu['Candidate'] == 'Trump') & (df_noNeu['News_Source'] == 'NYT')].hist(column=['pos'],bins=20);

# %% [markdown]
# # Clinton Sentiment Analysis

# %% [markdown]
# ### CNN Articles

# %%
df_noNeu.loc[(df_noNeu['Candidate'] == 'Hillary') & (df_noNeu['News_Source'] == 'CNN')].hist(column=['neg'],bins=20);

# %%
df_noNeu.loc[(df_noNeu['Candidate'] == 'Hillary') & (df_noNeu['News_Source'] == 'CNN')].hist(column=['pos'],bins=20);

# %% [markdown]
# ### Breitbart Articles

# %%
df_noNeu.loc[(df_noNeu['Candidate'] == 'Hillary') & (df_noNeu['News_Source'] == 'Breitbart')].hist(column=['neg'],bins=20);

# %%
df_noNeu.loc[(df_noNeu['Candidate'] == 'Hillary') & (df_noNeu['News_Source'] == 'Breitbart')].hist(column=['pos'],bins=20);

# %% [markdown]
# ### New York Times Articles

# %%
df_noNeu.loc[(df_noNeu['Candidate'] == 'Hillary') & (df_noNeu['News_Source'] == 'NYT')].hist(column=['neg'],bins=20);

# %%
df_noNeu.loc[(df_noNeu['Candidate'] == 'Hillary') & (df_noNeu['News_Source'] == 'NYT')].hist(column=['pos'],bins=20);

# %% [markdown]
# # Little Neutral Article Visualization
#
# Just for fun, we will do the same thing, but with an even lower neutral threshold of 0.5, just to visualize the data for the sentimentally charged articles

# %%
df_noNeu = df.loc[(df['neu'] < 0.5)]

# %% [markdown]
# # Trump Sentiment Analysis

# %% [markdown]
# ### CNN Articles

# %%
df_noNeu.loc[(df_noNeu['Candidate'] == 'Trump') & (df_noNeu['News_Source'] == 'CNN')].hist(column=['neg'],bins=20);

# %%
df_noNeu.loc[(df_noNeu['Candidate'] == 'Trump') & (df_noNeu['News_Source'] == 'CNN')].hist(column=['pos'],bins=20);

# %% [markdown]
# ### Breitbart Articles

# %%
df_noNeu.loc[(df_noNeu['Candidate'] == 'Trump') & (df_noNeu['News_Source'] == 'Breitbart')].hist(column=['neg'],bins=20);

# %%
df_noNeu.loc[(df_noNeu['Candidate'] == 'Trump') & (df_noNeu['News_Source'] == 'Breitbart')].hist(column=['pos'],bins=20);

# %% [markdown]
# ### New York Times Articles

# %%
df_noNeu.loc[(df_noNeu['Candidate'] == 'Trump') & (df_noNeu['News_Source'] == 'NYT')].hist(column=['neg'],bins=20);

# %%
df_noNeu.loc[(df_noNeu['Candidate'] == 'Trump') & (df_noNeu['News_Source'] == 'NYT')].hist(column=['pos'],bins=20);

# %% [markdown]
# # Clinton Sentiment Analysis

# %% [markdown]
# ### CNN Articles

# %%
df_noNeu.loc[(df_noNeu['Candidate'] == 'Hillary') & (df_noNeu['News_Source'] == 'CNN')].hist(column=['neg'],bins=20);

# %%
df_noNeu.loc[(df_noNeu['Candidate'] == 'Hillary') & (df_noNeu['News_Source'] == 'CNN')].hist(column=['pos'],bins=20);

# %% [markdown]
# ### Breitbart Articles

# %%
df_noNeu.loc[(df_noNeu['Candidate'] == 'Hillary') & (df_noNeu['News_Source'] == 'Breitbart')].hist(column=['neg'],bins=20);

# %%
df_noNeu.loc[(df_noNeu['Candidate'] == 'Hillary') & (df_noNeu['News_Source'] == 'Breitbart')].hist(column=['pos'],bins=20);

# %% [markdown]
# ### New York Times Articles

# %%
df_noNeu.loc[(df_noNeu['Candidate'] == 'Hillary') & (df_noNeu['News_Source'] == 'NYT')].hist(column=['neg'],bins=20);

# %%
df_noNeu.loc[(df_noNeu['Candidate'] == 'Hillary') & (df_noNeu['News_Source'] == 'NYT')].hist(column=['pos'],bins=20);
